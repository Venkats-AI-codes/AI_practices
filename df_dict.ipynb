# %% [markdown]
# <a href="https://colab.research.google.com/github/Venkats-AI-codes/AI_practices/blob/main/df_dict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Creating DataFrame from Dictionary of Array/list

# %% [markdown]
# 1. using pd.DataFrame

# %%
import pandas as pd
data = {'Category': ['Array', 'Stack', 'Queue'], 'Marks': [20, 21, 19]}
df = pd.DataFrame(data)
df
# Out:
#   Category  Marks
# 0    Array     20
# 1    Stack     21
# 2    Queue     19

# %% [markdown]
# 2. Using pd.DataFrame() with multiple columns
# When multiple value lists/arrays are given in dictionary, pd.DataFrame() can directly construct a DataFrame with multiple columns

# %%
data = {'Category': ['Array', 'Stack', 'Queue'], 'Student_1': [20, 21, 19], 'Student_2': [15, 20, 14]}
df = pd.DataFrame(data)
df
#df.transpose()
# Out:
#   Category  Student_1  Student_2
# 0    Array         20         15
# 1    Stack         21         20
# 2    Queue         19         14

# %% [markdown]
# 3. pd.DataFrame() with custome index
# It allows to assign custome labels to rows instead default integer indices.

# %%
df = pd.DataFrame(data, index=['cat_1', 'cat_2', 'cat_3'])
df
# Out:
#       Category  Student_1  Student_2
# cat_1    Array         20         15
# cat_2    Stack         21         20
# cat_3    Queue         19         14
